# %%
from pymongo import MongoClient
client = MongoClient()

# %%
client = MongoClient('mongodb://sp241930:100rabhh@ds139435.mlab.com:39435/cmc')

# %%
db = db = client['cmc']

# %%
import json

json_object = json.load(open("sample_data.json"))

json_object
# Out:
# [{'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA ONICIATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '100',
#   'Block Batch Number': 'LI00547',
#   'Material': '30029509',
#   'Material description': 'HNMS BC.ONC_IT-18MM-IMFG'},
#  {'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA ONICIATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '27',
#   'Block Batch Number': 'LI02577',
#   'Material': '30029509',
#   'Material description': 'HNMS BC.ONC_IT-18MM-IMFG'},
#  {'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
#   'Mara-Quality Name': 'BRECCIA ONICIATA',
#   'Storage location': '1130',
#   'Hanger and Angle': '100',
#   'Block Batch Number': 'LI00547',
#   'Material': '30029929',
#   'Material description': 'PNMS BC.ONC_IT-18MM-IMFG'},
#  {'Colour': 'BEIGE',
#   'Basic Material': 'NATURAL MARBLE SLABS',
# ...

# %%
marbles = db['marbles']

# %%
for e in json_object:
    marble_info = e
    marble_hash_id = marbles.insert_one(marble_info).inserted_id
    print(marble_hash_id)
# Out:
# 5ef032baf0f14420fd440c6e
# 5ef032bbf0f14420fd440c6f
# 5ef032bbf0f14420fd440c70
# 5ef032bbf0f14420fd440c71
# 5ef032bcf0f14420fd440c72
# 5ef032bcf0f14420fd440c73
# 5ef032bcf0f14420fd440c74
# 5ef032bcf0f14420fd440c75
# 5ef032bcf0f14420fd440c76
# 5ef032bcf0f14420fd440c77
# 5ef032bcf0f14420fd440c78
# 5ef032bdf0f14420fd440c79
# 5ef032bdf0f14420fd440c7a
# 5ef032bdf0f14420fd440c7b
# 5ef032bdf0f14420fd440c7c
# 5ef032bdf0f14420fd440c7d
# 5ef032bdf0f14420fd440c7e
# 5ef032bdf0f14420fd440c7f
# 5ef032bef0f14420fd440c80
# 5ef032bef0f14420fd440c81
# 5ef032bef0f14420fd440c82
# 5ef032bef0f14420fd440c83
# 5ef032bef0f14420fd440c84
# 5ef032bef0f14420fd440c85
# 5ef032bef0f14420fd440c86
# 5ef032bef0f14420fd440c87
# 5ef032bff0f14420fd440c88
# 5ef032bff0f14420fd440c89
# 5ef032bff0f14420fd440c8a
# 5ef032bff0f14420fd440c8b
# 5ef032bff0f14420fd440c8c
# 5ef032bff0f14420fd440c8d
# 5ef032bff0f14420fd440c8e
# 5ef032c0f0f14420fd440c8f
# 5ef032c0f0f14420fd440c90
# 5ef032c0f0f14420fd440c91
# 5ef032c0f0f14420fd440c92
# ...

# %%
output_data = marbles.find({'$text':{'$search':"brown terracotta"}})

for d in output_data:
    print(d)
# Out:
# {'_id': ObjectId('5ef032e6f0f14420fd440d6e'), 'Colour': 'BROWN', 'Basic Material': 'NATURAL MARBLE SLABS', 'Mara-Quality Name': 'VENICE BROWN', 'Storage location': '1130', 'Hanger and Angle': '68', 'Block Batch Number': '11KJ064', 'Material': '40001050', 'Material description': 'PNMS VNC.BRN_CN-18MM-IMP'}
# {'_id': ObjectId('5ef032e6f0f14420fd440d6d'), 'Colour': 'BROWN', 'Basic Material': 'NATURAL MARBLE SLABS', 'Mara-Quality Name': 'VENICE BROWN', 'Storage location': '1130', 'Hanger and Angle': '62', 'Block Batch Number': '11KJ070', 'Material': '40001050', 'Material description': 'PNMS VNC.BRN_CN-18MM-IMP'}
# {'_id': ObjectId('5ef032e5f0f14420fd440d6b'), 'Colour': 'BROWN', 'Basic Material': 'NATURAL MARBLE SLABS', 'Mara-Quality Name': 'TOBACCO BROWN', 'Storage location': '1130', 'Hanger and Angle': '58', 'Block Batch Number': 'LF62916A', 'Material': '30030212', 'Material description': 'PNMS TBC.BRN_CA-20MM-IMFG'}
# ...
